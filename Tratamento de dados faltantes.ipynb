# %% [markdown]
# # Relatório de Análises V

# %% [markdown]
# ## Tratamento de dados faltantes

# %%
import pandas as pd

# %%
dados = pd.read_csv("dados/aluguel_residencial.csv", sep = ";")
dados
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento          Vista Alegre        3      1       0    70
# ...            ...                   ...      ...    ...     ...   ...
# 23367  Apartamento                 Méier        2      0       0    70
# 23368    Quitinete                Centro        0      0       0    27
# 23369  Apartamento           Jacarepaguá        3      1       2    78
# 23370  Apartamento  São Francisco Xavier        2      1       0    48
# 23371  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 0      1700.0       500.0  60.0
# 1      7000.0         NaN   NaN
# ...

# %%
dados.isnull()
# Out:
#         Tipo  Bairro  Quartos  Vagas  Suites   Area  Valor  Condominio   IPTU
# 0      False   False    False  False   False  False  False       False  False
# 1      False   False    False  False   False  False  False        True   True
# 2      False   False    False  False   False  False  False       False  False
# 3      False   False    False  False   False  False  False       False   True
# 4      False   False    False  False   False  False  False        True   True
# ...      ...     ...      ...    ...     ...    ...    ...         ...    ...
# 23367  False   False    False  False   False  False  False       False  False
# 23368  False   False    False  False   False  False  False       False  False
# 23369  False   False    False  False   False  False  False       False  False
# 23370  False   False    False  False   False  False  False       False  False
# 23371  False   False    False  False   False  False  False       False   True
#
# [23372 rows x 9 columns]

# %%
dados.notnull()
# Out:
#        Tipo  Bairro  Quartos  Vagas  Suites  Area  Valor  Condominio   IPTU
# 0      True    True     True   True    True  True   True        True   True
# 1      True    True     True   True    True  True   True       False  False
# 2      True    True     True   True    True  True   True        True   True
# 3      True    True     True   True    True  True   True        True  False
# 4      True    True     True   True    True  True   True       False  False
# ...     ...     ...      ...    ...     ...   ...    ...         ...    ...
# 23367  True    True     True   True    True  True   True        True   True
# 23368  True    True     True   True    True  True   True        True   True
# 23369  True    True     True   True    True  True   True        True   True
# 23370  True    True     True   True    True  True   True        True   True
# 23371  True    True     True   True    True  True   True        True  False
#
# [23372 rows x 9 columns]

# %%
a = dados.shape[0]
dados.dropna(subset=['Valor'], inplace=True)
b = dados.shape[0]
a - b
# Out:
# 9

# %%
dados['Valor'].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 23367    False
# 23368    False
# 23369    False
# 23370    False
# 23371    False
# Name: Valor, Length: 23363, dtype: bool

# %%
dados.loc[dados['Valor'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Tipo, Bairro, Quartos, Vagas, Suites, Area, Valor, Condominio, IPTU]
# Index: []

# %% [markdown]
# ## Tratamento de dados faltantes - continuação

# %%
dados[dados['Condominio'].isnull()].shape[0]
# Out:
# 2142

# %%
selecao = (dados['Tipo'] != 'Apartamento') & (dados['Condominio'].notnull()) 
a = dados.shape[0]
dados_condominio = dados[selecao]
b = dado_condominio.shape[0]
a-b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-5eebd7a5e02a> in <module>
#       2 a = dados.shape[0]
#       3 dados_condominio = dados[selecao]
# ----> 4 b = dado_condominio.shape[0]
#       5 a-b
#
# NameError: name 'dado_condominio' is not defined

# %%
selecao = (dados['Tipo'] != 'Apartamento') & (dados['Condominio'].notnull()) 
a = dados.shape[0]
dados_condominio = dados[selecao]
b = dados_condominio.shape[0]
a-b
# Out:
# 20922

# %%
selecao = (dados['Tipo'] == 'Apartamento') & (dados['Condominio'].isnull()) 
a = dados.shape[0]
dados_condominio1 = dados[~selecao]
b = dados_condominio1.shape[0]
a-b
# Out:
# 745

# %%
dados.fillna(0, inplace=True)

# %%
dados
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento          Vista Alegre        3      1       0    70
# ...            ...                   ...      ...    ...     ...   ...
# 23367  Apartamento                 Méier        2      0       0    70
# 23368    Quitinete                Centro        0      0       0    27
# 23369  Apartamento           Jacarepaguá        3      1       2    78
# 23370  Apartamento  São Francisco Xavier        2      1       0    48
# 23371  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 0      1700.0       500.0  60.0
# 1      7000.0         0.0   0.0
# ...

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23363 entries, 0 to 23371
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tipo        23363 non-null  object
#  1   Bairro      23363 non-null  object
#  2   Quartos     23363 non-null  int64
#  3   Vagas       23363 non-null  int64
#  4   Suites      23363 non-null  int64
#  5   Area        23363 non-null  int64
#  6   Valor       23363 non-null  float64
#  7   Condominio  23363 non-null  float64
#  8   IPTU        23363 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.8+ MB

# %%
dados.to_csv("dados/aluguel_residencial.csv", sep = ";", index =False)
